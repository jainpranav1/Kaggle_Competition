# %% [markdown]
# # Baselines (1, 2)

# %%
# import the libraries
import dask.dataframe as dd
from dask_ml.model_selection import train_test_split
from dask_ml.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /root/venv/lib/python3.9/site-packages/dask/dataframe/_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 9.0.0. Please consider upgrading.
#   warnings.warn(

# %%
# import and see train_data.csv
df_train_csv = dd.read_csv('Data/train_data.csv')
df_train_csv.head()
# Out:
#     sequence_id                                           sequence  \
# 0  8cdfeef009ea  GGGAACGACUCGAGUAGAGUCGAAAAACGUUGAUAUGGAUUUACUC...
# 1  51e61fbde94d  GGGAACGACUCGAGUAGAGUCGAAAAACAUUGAUAUGGAUUUACUC...
# 2  25ce8d5109cd  GGGAACGACUCGAGUAGAGUCGAAAAACCUUGAUAUGGAUUUACUC...
# 3  07dcfb6d1965  GGGAACGACUCGAGUAGAGUCGAAAAACUUUGAUAUGGAUUUACUC...
# 4  e561cc042a4c  GGGAACGACUCGAGUAGAGUCGAAAAACGAUGAUAUGGAUUUACUC...
#
#   experiment_type dataset_name   reads  signal_to_noise  SN_filter  \
# 0         2A3_MaP      15k_2A3    2343            0.944          0
# 1         2A3_MaP      15k_2A3    5326            1.933          1
# 2         2A3_MaP      15k_2A3    4647            2.347          1
# 3         2A3_MaP      15k_2A3  102843           11.824          1
# 4         2A3_MaP      15k_2A3    7665            3.519          1
#
#    reactivity_0001  reactivity_0002  reactivity_0003  ...  \
# 0              NaN              NaN              NaN  ...
# 1              NaN              NaN              NaN  ...
# 2              NaN              NaN              NaN  ...
# 3              NaN              NaN              NaN  ...
# 4              NaN              NaN              NaN  ...
#
#    reactivity_error_0197  reactivity_error_0198  reactivity_error_0199  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    reactivity_error_0200  reactivity_error_0201  reactivity_error_0202  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    reactivity_error_0203  reactivity_error_0204  reactivity_error_0205  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    reactivity_error_0206
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 419 columns]

# %%
# apply SN-filter
df_sn = df_train_csv[df_train_csv["SN_filter"]==1]

# split into 2A3 MaP and DMS MaP datasets
df_2A3 = df_sn[df_sn["experiment_type"]=="2A3_MaP"]
df_DMS = df_sn[df_sn["experiment_type"]=="DMS_MaP"]

# split into train, validate, test
X_2A3 = df_2A3["sequence"]
y_2A3 = df_2A3.loc[:, df_2A3.columns.str.fullmatch("reactivity_\d\d\d\d")]
X_2A3_train_valid, X_2A3_test, y_2A3_train_valid, y_2A3_test = train_test_split(X_2A3, y_2A3, test_size=0.2, shuffle=True, blockwise=True, random_state=42)
X_2A3_train, X_2A3_valid, y_2A3_train, y_2A3_valid = train_test_split(X_2A3_train_valid, y_2A3_train_valid, test_size=0.25, shuffle=True, blockwise=True, random_state=42)

X_DMS = df_DMS["sequence"]
y_DMS = df_DMS.loc[:, df_DMS.columns.str.fullmatch("reactivity_\d\d\d\d")]
X_DMS_train_valid, X_DMS_test, y_DMS_train_valid, y_DMS_test = train_test_split(X_DMS, y_DMS, test_size=0.2, shuffle=True, blockwise=True, random_state=42)
X_DMS_train, X_DMS_valid, y_DMS_train, y_DMS_valid = train_test_split(X_DMS_train_valid, y_DMS_train_valid, test_size=0.25, shuffle=True, blockwise=True, random_state=42)

# %%
# import and see train_sequences.csv
df_test_csv = dd.read_csv('Data/test_sequences.csv')
df_test_csv.head()
# Out:
#    id_min  id_max   sequence_id  \
# 0       0     176  eee73c1836bc
# 1     177     353  d2a929af7a97
# 2     354     530  d39a4425ff45
# 3     531     707  1fc41e92d553
# 4     708     884  1d0826fb892f
#
#                                             sequence  future
# 0  GGGAACGACUCGAGUAGAGUCGAAAAUUUCCUUCCAAAUCCUGAGG...       0
# 1  GGGAACGACUCGAGUAGAGUCGAAAAUGUAAUCAGAUUGCUUCUCC...       0
# 2  GGGAACGACUCGAGUAGAGUCGAAAAAACACAUGAAUUUGAGGGUU...       0
# 3  GGGAACGACUCGAGUAGAGUCGAAAAUCAGAGCUGGCAAAUGGAUG...       0
# 4  GGGAACGACUCGAGUAGAGUCGAAAAUUUGGUAUUUGAUGCAUUAA...       0

# %%
# create mutate and map dataset
id1=269545321
id2=269724007
df_mmap = df_test_csv[(id1 <= df_test_csv["id_min"]) & (df_test_csv["id_max"] <= id2)]["sequence"]

# %% [markdown]
# ## Baseline 1

# %% [markdown]
# - Bound the reactivities in y_*_train between 0 and 1

# %% [markdown]
# - Determine the average of the bounded reactivities

# %% [markdown]
# - Use the average to predict all the reactivities in y_*_test

# %%
# 2A3 MAE
avg_bnd_react = y_2A3_train.clip(0, 1).mean(axis=None)
mean_absolute_error(y_2A3_test.clip(0, 1), avg_bnd_react)
# Out:
# 0.2937951817405886

# %%
# 2A3 MMAP
df_mmap_pred = df_mmap.str.split(pat="(?<=[AUGC])(?=[AUGC])", n=456, expand=True)
df_mmap_pred[df_mmap_pred==df_mmap_pred] = avg_bnd_react
df_mmap_pred = df_mmap_pred.astype("float")
plt.imshow(df_mmap_pred.compute())
plt.title("Mutate and Map Dataset Predictions")
plt.xlabel("Position")
plt.ylabel("Sequence")
plt.show()

# %%
# DMS MAE
avg_bnd_react = y_DMS_train.clip(0, 1).mean(axis=None)
mean_absolute_error(y_DMS_test.clip(0, 1), avg_bnd_react)
# Out:
# 0.29694372187197526

# %%
# DMS MMAP
df_mmap_pred = df_mmap.str.split(pat="(?<=[AUGC])(?=[AUGC])", n=456, expand=True)
df_mmap_pred[df_mmap_pred==df_mmap_pred] = avg_bnd_react
df_mmap_pred = df_mmap_pred.astype("float")
plt.imshow(df_mmap_pred.compute())
plt.title("Mutate and Map Dataset Predictions")
plt.xlabel("Position")
plt.ylabel("Sequence")
plt.show()

# %% [markdown]
# ## Baseline 2

# %% [markdown]
# - Bound the reactivities in y_*_train between 0 and 1

# %% [markdown]
# - For A, U, G, and C, determine the average of all the bounded reactivities in y_*_train for the base

# %% [markdown]
# - Use the four averages to predict all the reactivities in y_*_test

# %%
# 2A3 MAE
seq_mat_train = X_2A3_train.\
str.pad(width=206, side="right", fillchar="N").\
str.split(pat="(?<=[AUGCN])(?=[AUGCN])", n=205, expand=True)
seq_mat_train.columns = y_2A3_train.columns

avg_bnd_react_A = y_2A3_train[seq_mat_train=="A"].clip(0, 1).mean(axis=None)
avg_bnd_react_U = y_2A3_train[seq_mat_train=="U"].clip(0, 1).mean(axis=None)
avg_bnd_react_G = y_2A3_train[seq_mat_train=="G"].clip(0, 1).mean(axis=None)
avg_bnd_react_C = y_2A3_train[seq_mat_train=="C"].clip(0, 1).mean(axis=None)

seq_mat_test = X_2A3_test.\
str.pad(width=206, side="right", fillchar="N").\
str.split(pat="(?<=[AUGCN])(?=[AUGCN])", n=205, expand=True)
seq_mat_test.columns = y_2A3_test.columns

avg_bnd_react_AUGC = seq_mat_test
avg_bnd_react_AUGC[seq_mat_test=="A"] = avg_bnd_react_A
avg_bnd_react_AUGC[seq_mat_test=="U"] = avg_bnd_react_U
avg_bnd_react_AUGC[seq_mat_test=="G"] = avg_bnd_react_G
avg_bnd_react_AUGC[seq_mat_test=="C"] = avg_bnd_react_C
avg_bnd_react_AUGC[seq_mat_test=="N"] = np.nan
avg_bnd_react_AUGC = avg_bnd_react_AUGC.astype("float")

mean_absolute_error(y_2A3_test.clip(0, 1), avg_bnd_react_AUGC)
# Out:
# 0.28119789510061677

# %%
# 2A3 MMAP
df_mmap_pred = df_mmap.str.split(pat="(?<=[AUGC])(?=[AUGC])", n=456, expand=True)
df_mmap_pred[df_mmap_pred == "A"] = avg_react_A
df_mmap_pred[df_mmap_pred == "U"] = avg_react_U
df_mmap_pred[df_mmap_pred == "G"] = avg_react_G
df_mmap_pred[df_mmap_pred == "C"] = avg_react_C
df_mmap_pred = df_mmap_pred.astype("float")
df_mmap_pred = df_mmap_pred.clip(0, 1)
plt.imshow(df_mmap_pred.compute())
plt.title("Mutate and Map Dataset Predictions")
plt.xlabel("Position")
plt.ylabel("Sequence")
plt.show()

# %%
# DMS MAE
seq_mat_train = X_DMS_train.\
str.pad(width=206, side="right", fillchar="N").\
str.split(pat="(?<=[AUGCN])(?=[AUGCN])", n=205, expand=True)
seq_mat_train.columns = y_DMS_train.columns

avg_bnd_react_A = y_DMS_train[seq_mat_train=="A"].clip(0, 1).mean(axis=None)
avg_bnd_react_U = y_DMS_train[seq_mat_train=="U"].clip(0, 1).mean(axis=None)
avg_bnd_react_G = y_DMS_train[seq_mat_train=="G"].clip(0, 1).mean(axis=None)
avg_bnd_react_C = y_DMS_train[seq_mat_train=="C"].clip(0, 1).mean(axis=None)

seq_mat_test = X_DMS_test.\
str.pad(width=206, side="right", fillchar="N").\
str.split(pat="(?<=[AUGCN])(?=[AUGCN])", n=205, expand=True)
seq_mat_test.columns = y_DMS_test.columns

avg_bnd_react_AUGC = seq_mat_test
avg_bnd_react_AUGC[seq_mat_test=="A"] = avg_bnd_react_A
avg_bnd_react_AUGC[seq_mat_test=="U"] = avg_bnd_react_U
avg_bnd_react_AUGC[seq_mat_test=="G"] = avg_bnd_react_G
avg_bnd_react_AUGC[seq_mat_test=="C"] = avg_bnd_react_C
avg_bnd_react_AUGC[seq_mat_test=="N"] = np.nan
avg_bnd_react_AUGC = avg_bnd_react_AUGC.astype("float")

mean_absolute_error(y_DMS_test.clip(0, 1), avg_bnd_react_AUGC)
# Out:
# 0.21872587614546893

# %%
# DMS MMAP
df_mmap_pred = df_mmap.str.split(pat="(?<=[AUGC])(?=[AUGC])", n=456, expand=True)
df_mmap_pred[df_mmap_pred == "A"] = avg_react_A
df_mmap_pred[df_mmap_pred == "U"] = avg_react_U
df_mmap_pred[df_mmap_pred == "G"] = avg_react_G
df_mmap_pred[df_mmap_pred == "C"] = avg_react_C
df_mmap_pred = df_mmap_pred.astype("float")
df_mmap_pred = df_mmap_pred.clip(0, 1)
plt.imshow(df_mmap_pred.compute())
plt.title("Mutate and Map Dataset Predictions")
plt.xlabel("Position")
plt.ylabel("Sequence")
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fe343e39-d2c0-4296-915d-091d9a42752d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
