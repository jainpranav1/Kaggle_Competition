# %% [markdown]
# # Initialization Notebook

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: dask[complete] in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 1)) (2023.10.1)
# Requirement already satisfied: dask-ml[complete] in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (2023.3.24)
# Requirement already satisfied: kaggle in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 3)) (1.5.16)
# Requirement already satisfied: fsspec>=2021.09.0 in /root/venv/lib/python3.9/site-packages (from dask[complete]->-r ./requirements.txt (line 1)) (2023.10.0)
# Requirement already satisfied: click>=8.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from dask[complete]->-r ./requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from dask[complete]->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: partd>=1.2.0 in /root/venv/lib/python3.9/site-packages (from dask[complete]->-r ./requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from dask[complete]->-r ./requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /root/venv/lib/python3.9/site-packages (from dask[complete]->-r ./requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /root/venv/lib/python3.9/site-packages (from dask[complete]->-r ./requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from dask[complete]->-r ./requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: pyarrow>=7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from dask[complete]->-r ./requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: lz4>=4.3.2 in /root/venv/lib/python3.9/site-packages (from dask[complete]->-r ./requirements.txt (line 1)) (4.3.2)
# Requirement already satisfied: scipy in /shared-libs/python3.9/py/lib/python3.9/site-packages (from dask-ml[complete]->-r ./requirements.txt (line 2)) (1.9.3)
# Requirement already satisfied: pandas>=0.24.2 in /root/venv/lib/python3.9/site-packages (from dask-ml[complete]->-r ./requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: multipledispatch>=0.4.9 in /root/venv/lib/python3.9/site-packages (from dask-ml[complete]->-r ./requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: scikit-learn>=1.2.0 in /root/venv/lib/python3.9/site-packages (from dask-ml[complete]->-r ./requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: dask-glm>=0.2.0 in /root/venv/lib/python3.9/site-packages (from dask-ml[complete]->-r ./requirements.txt (line 2)) (0.3.1)
# Requirement already satisfied: distributed>=2.4.0 in /root/venv/lib/python3.9/site-packages (from dask-ml[complete]->-r ./requirements.txt (line 2)) (2023.10.1)
# Requirement already satisfied: numba>=0.51.0 in /root/venv/lib/python3.9/site-packages (from dask-ml[complete]->-r ./requirements.txt (line 2)) (0.58.1)
# Requirement already satisfied: numpy>=1.20.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from dask-ml[complete]->-r ./requirements.txt (line 2)) (1.23.4)
# Requirement already satisfied: xgboost in /root/venv/lib/python3.9/site-packages (from dask-ml[complete]->-r ./requirements.txt (line 2)) (0.90)
# Requirement already satisfied: dask-xgboost in /root/venv/lib/python3.9/site-packages (from dask-ml[complete]->-r ./requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: urllib3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from kaggle->-r ./requirements.txt (line 3)) (1.26.12)
# Requirement already satisfied: python-dateutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from kaggle->-r ./requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: six>=1.10 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from kaggle->-r ./requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: requests in /shared-libs/python3.9/py/lib/python3.9/site-packages (from kaggle->-r ./requirements.txt (line 3)) (2.28.1)
# Requirement already satisfied: certifi in /shared-libs/python3.9/py/lib/python3.9/site-packages (from kaggle->-r ./requirements.txt (line 3)) (2022.9.24)
# Requirement already satisfied: python-slugify in /shared-libs/python3.9/py/lib/python3.9/site-packages (from kaggle->-r ./requirements.txt (line 3)) (6.1.2)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from kaggle->-r ./requirements.txt (line 3)) (4.64.1)
# Requirement already satisfied: bleach in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from kaggle->-r ./requirements.txt (line 3)) (5.0.1)
# Requirement already satisfied: sparse>=0.7.0 in /root/venv/lib/python3.9/site-packages (from dask-glm>=0.2.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: jinja2>=2.10.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from distributed>=2.4.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: tornado>=6.0.4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from distributed>=2.4.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (6.2)
# Requirement already satisfied: psutil>=5.7.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from distributed>=2.4.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (5.9.3)
# Requirement already satisfied: zict>=3.0.0 in /root/venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: tblib>=1.6.0 in /root/venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /root/venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: locket>=1.0.0 in /root/venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /root/venv/lib/python3.9/site-packages (from distributed>=2.4.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (1.0.7)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask[complete]->-r ./requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /root/venv/lib/python3.9/site-packages (from numba>=0.51.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (0.41.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=20.0->dask[complete]->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.24.2->dask-ml[complete]->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.24.2->dask-ml[complete]->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=1.2.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn>=1.2.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: webencodings in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from bleach->kaggle->-r ./requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: bokeh>=2.4.2 in /root/venv/lib/python3.9/site-packages (from dask[complete]->-r ./requirements.txt (line 1)) (3.3.1)
# Requirement already satisfied: text-unidecode>=1.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from python-slugify->kaggle->-r ./requirements.txt (line 3)) (1.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->kaggle->-r ./requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->kaggle->-r ./requirements.txt (line 3)) (3.4)
# Requirement already satisfied: pillow>=7.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from bokeh>=2.4.2->dask[complete]->-r ./requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: contourpy>=1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from bokeh>=2.4.2->dask[complete]->-r ./requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: xyzservices>=2021.09.1 in /root/venv/lib/python3.9/site-packages (from bokeh>=2.4.2->dask[complete]->-r ./requirements.txt (line 1)) (2023.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jinja2>=2.10.3->distributed>=2.4.0->dask-ml[complete]->-r ./requirements.txt (line 2)) (2.0.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fe343e39-d2c0-4296-915d-091d9a42752d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
